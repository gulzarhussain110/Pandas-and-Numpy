# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('8. Netflix Dataset.csv')

# %%
df.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#   Release_Date Rating   Duration  \
# 0    14-Aug-20  TV-MA  4 Seasons
# 1    23-Dec-16  TV-MA     93 min
# 2    20-Dec-18      R     78 min
# 3    16-Nov-17  PG-13     80 min
# 4     1-Jan-20  PG-13    123 min
#
#                                                 Type  \
# ...

# %%
df.describe()
# Out:
#        Show_Id Category              Title                Director  \
# count     7789     7789               7789                    5401
# unique    7787        2               7787                    4050
# top      s6621    Movie  The Lost Okoroshi  Raúl Campos, Jan Suter
# freq         2     5379                  2                      18
#
#                       Cast        Country Release_Date Rating  Duration  \
# count                 7071           7282         7779   7782      7789
# unique                6831            681         1565     14       216
# top     David Attenborough  United States     1-Jan-20  TV-MA  1 Season
# freq                    18           2556          118   2865      1608
#
#                  Type                                        Description
# count            7789                                               7789
# unique            492                                               7769
# ...

# %%
df.dropna(subset=['Director'],inplace=True)

# %%
df.shape
# Out:
# (5401, 11)

# %%
df
# Out:
#      Show_Id Category                                    Title  \
# 1         s2    Movie                                     7:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# 5         s6  TV Show                                       46
# ...      ...      ...                                      ...
# 7782   s7781    Movie                                      Zoo
# 7783   s7782    Movie                                     Zoom
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 1     Jorge Michel Grau  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# ...

# %%
df.shape
# Out:
# (5401, 11)

# %%
df.dropna(subset=['Cast'],inplace=True)

# %%
df
# Out:
#      Show_Id Category       Title           Director  \
# 1         s2    Movie        7:19  Jorge Michel Grau
# 2         s3    Movie       23:59       Gilbert Chan
# 3         s4    Movie           9        Shane Acker
# 4         s5    Movie          21     Robert Luketic
# 5         s6  TV Show          46        Serdar Akar
# ...      ...      ...         ...                ...
# 7780   s7779    Movie  Zombieland    Ruben Fleischer
# 7782   s7781    Movie         Zoo       Shlok Sharma
# 7783   s7782    Movie        Zoom       Peter Hewitt
# 7784   s7783    Movie        Zozo        Josef Fares
# 7785   s7784    Movie      Zubaan        Mozez Singh
#
#                                                    Cast  \
# 1     Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# 2     Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# 3     Elijah Wood, John C. Reilly, Jennifer Connelly...
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# ...

# %%
df['Cast'].value_counts()
# Out:
# Samuel West                                                                                                                                                                                          10
# Jeff Dunham                                                                                                                                                                                           7
# Kevin Hart                                                                                                                                                                                            6
# Bill Burr                                                                                                                                                                                             5
# ...

# %%
df['Director'].value_counts()
# Out:
# Raúl Campos, Jan Suter             18
# Marcus Raboy                       16
# Jay Karas                          14
# Cathy Garcia-Molina                13
# Jay Chapman                        12
#                                    ..
# Hardik Mehta                        1
# Matt Eskandari                      1
# Eric Laneuville                     1
# Robert Osman, Nathanael Wiseman     1
# Mozez Singh                         1
# Name: Director, Length: 3712, dtype: int64

# %%
df['Director'].group_by.means()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\DELLLA~1\AppData\Local\Temp/ipykernel_1992/2115189416.py in <module>
# ----> 1 df['Director'].group_by.means()
#
# E:\anaconda\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'group_by'

# %%
df.group_by['Direcotr'].means()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\DELLLA~1\AppData\Local\Temp/ipykernel_1992/843003225.py in <module>
# ----> 1 df.group_by['Direcotr'].means()
#
# E:\anaconda\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'group_by'

# %%
df.groupby['Director'].mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\DELLLA~1\AppData\Local\Temp/ipykernel_1992/593713563.py in <module>
# ----> 1 df.groupby['Director'].mean()
#
# TypeError: 'method' object is not subscriptable

# %%
df1=df.groupby['Director'].mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\DELLLA~1\AppData\Local\Temp/ipykernel_1992/506520162.py in <module>
# ----> 1 df1=df.groupby['Director'].mean()
#
# TypeError: 'method' object is not subscriptable

# %%
df.groupby('Director').mean()
# Out:
# E:\anaconda\lib\site-packages\IPython\core\interactiveshell.py:3444: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Empty DataFrame
# Columns: []
# ...

# %%
df2=df.groupby("Director").mean()
# Out:
# E:\anaconda\lib\site-packages\IPython\core\interactiveshell.py:3444: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df2.reset_index(inplace=True)

# %%
df2
# Out:
#                  Director
# 0             A. L. Vijay
# 1            A. Raajdheep
# 2               A. Salaam
# 3         A.R. Murugadoss
# 4         Aadish Keluskar
# ...                   ...
# 3707          Çagan Irmak
# 3708     Ísold Uggadóttir
# 3709  Óskar Thór Axelsson
# 3710     Ömer Faruk Sorak
# 3711         Şenol Sönmez
#
# [3712 rows x 1 columns]

# %%
df.sort_values(['Director'],ascending=True)
# Out:
#      Show_Id Category                  Title             Director  \
# 283     s284    Movie              Abhinetri          A. L. Vijay
# 7491   s7490    Movie               Watchman          A. L. Vijay
# 605     s606    Movie             Asura Guru         A. Raajdheep
# 5351   s5351    Movie              Salaakhen            A. Salaam
# 5396   s5396    Movie                 Sarkar      A.R. Murugadoss
# ...      ...      ...                    ...                  ...
# 41       s42    Movie             Ég man þig  Óskar Thór Axelsson
# 263     s264    Movie  Aşk Tesadüfleri Sever     Ömer Faruk Sorak
# 2324   s2325    Movie                G.O.R.A     Ömer Faruk Sorak
# 3380   s3381    Movie    Kill Me If You Dare         Şenol Sönmez
# 2661   s2662    Movie          Hayat Öpücügü         Şenol Sönmez
#
#                                                    Cast  Country Release_Date  \
# 283   Tamannaah Bhatia, Prabhu Deva, Sonu Sood, Sapt...    India     1-May-18
# ...

# %%
df[df['Country']=="India"]
# Out:
#      Show_Id Category                     Title            Director  \
# 8         s9    Movie                       706       Shravan Kumar
# 9        s10    Movie                      1920        Vikram Bhatt
# 18       s19    Movie                    15-Aug  Swapnaneel Jayakar
# 20       s21    Movie      ​​Kuch Bheege Alfaaz                Onir
# 21       s22    Movie              ​Goli Soda 2        Vijay Milton
# ...      ...      ...                       ...                 ...
# 7766   s7765    Movie                      Zero          Aanand Rai
# 7771   s7770    Movie  Zindagi Na Milegi Dobara         Zoya Akhtar
# 7778   s7777    Movie                  Zokkomon    Satyajit Bhatkal
# 7782   s7781    Movie                       Zoo        Shlok Sharma
# 7785   s7784    Movie                    Zubaan         Mozez Singh
#
#                                                    Cast Country Release_Date  \
# ...

# %%
df[(df['Country'].str.startswith(('T','t')))][['Director']]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\DELLLA~1\AppData\Local\Temp/ipykernel_1992/1671552439.py in <module>
# ----> 1 df[(df['Country'].str.startswith(('T','t')))][['Director']]
#
# E:\anaconda\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3446
#    3447         # Do we have a (boolean) 1d indexer?
# -> 3448         if com.is_bool_indexer(key):
#    3449             return self._getitem_bool_array(key)
#    3450
#
# E:\anaconda\lib\site-packages\pandas\core\common.py in is_bool_indexer(key)
#     137                     # Don't raise on e.g. ["A", "B", np.nan], see
#     138                     #  test_loc_getitem_list_of_labels_categoricalindex_with_na
# --> 139                     raise ValueError(na_msg)
#     140                 return False
#     141             return True
#
# ...

# %%
df.isnull().sum()
# Out:
# Show_Id           0
# Category          0
# Title             0
# Director          0
# Cast              0
# Country         167
# Release_Date      0
# Rating            4
# Duration          0
# Type              0
# Description       0
# dtype: int64

# %%
df.dropna(subset=['Country'],inplace=True)

# %%
df[(df["Country"].str.startswith(('T','t')))][['Country','Director',"Cast",'Title']]
# Out:
#        Country                 Director  \
# 5       Turkey              Serdar Akar
# 13    Thailand      Nottapon Boonprakob
# 40      Turkey          Muharrem Gülmez
# 42      Turkey             Ozan Açıktan
# 156     Turkey               Umut Kirca
# ...        ...                      ...
# 7708  Thailand  Saratswadee Wongsomphet
# 7709  Thailand  Saratswadee Wongsomphet
# 7710  Thailand        Kirati Nakintanon
# 7733    Turkey              Tolga Örnek
# 7743    Taiwan            Liu Kuang-hui
#
#                                                    Cast  \
# 5     Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...
# 13                                   Artiwara Kongmalai
# 40    Erdem Yener, Ayhan Taş, Emin Olcay, Muharrem G...
# 42    Ayça Erturan, Aydan Taş, Ayşegül Akdemir, Burc...
# 156   Emre Karayel, Ceren Moray, Begüm Kütük, Ececan...
# ...                                                 ...
# 7708  Sushar Manaying, Supanart Jittaleela, Arisara ...
# ...

# %%
df.sort_values(subset["Country"],ascending=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\DELLLA~1\AppData\Local\Temp/ipykernel_1992/585820148.py in <module>
# ----> 1 df.sort_values(subset["Country"],ascending=True)
#
# NameError: name 'subset' is not defined

# %%
df.sort_values(['Country'],ascending=True)
# Out:
#      Show_Id Category                     Title  \
# 1167   s1168    Movie           Caida del Cielo
# 1375   s1376    Movie    Chronicle of an Escape
# 3250   s3251    Movie                 Just Love
# 426     s427  TV Show              Almost Happy
# 2148   s2149    Movie  Fernando Sanjiao: Hombre
# ...      ...      ...                       ...
# 1482   s1483    Movie          Conjuring Spirit
# 939     s940    Movie             Bitcoin Heist
# 2318   s2319    Movie                     Furie
# 3105   s3106    Movie                   Jackpot
# 1493   s1494    Movie                  Cook Off
#
#                            Director  \
# 1167          Néstor Sánchez Sotelo
# 1375          Israel Adrián Caetano
# 3250  Andy Caballero, Diego Corsini
# 426               Hernán Guerschuny
# 2148         Raúl Campos, Jan Suter
# ...                             ...
# 1482                    Van M. Pham
# 939                        Ham Tran
# 2318                    Le Van Kiet
# ...

# %%
df.groupby('Country').mean()
# Out:
# E:\anaconda\lib\site-packages\IPython\core\interactiveshell.py:3444: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Empty DataFrame
# Columns: []
# ...

# %%
cat=df.groupby("Category").mean()

# %%
cat.reindex(inplace=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\DELLLA~1\AppData\Local\Temp/ipykernel_1992/3906483324.py in <module>
# ----> 1 cat.reindex(inplace=True)
#
# E:\anaconda\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     322         @wraps(func)
#     323         def wrapper(*args, **kwargs) -> Callable[..., Any]:
# --> 324             return func(*args, **kwargs)
#     325
#     326         kind = inspect.Parameter.POSITIONAL_OR_KEYWORD
#
# E:\anaconda\lib\site-packages\pandas\core\frame.py in reindex(self, *args, **kwargs)
#    4770         kwargs.pop("axis", None)
#    4771         kwargs.pop("labels", None)
# -> 4772         return super().reindex(**kwargs)
#    4773
#    4774     @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#
# ...

# %%
cat.reset_index(inplace=True)

# %%
cat
# Out:
#   Category
# 0    Movie
# 1  TV Show

# %%
df['Category'].value_counts()
# Out:
# Movie      4679
# TV Show     136
# Name: Category, dtype: int64

# %%
df.Category.unique()
# Out:
# array(['Movie', 'TV Show'], dtype=object)

# %%
df['Category'].unique()
# Out:
# array(['Movie', 'TV Show'], dtype=object)
